# %% [markdown]
# ![](./img/dl_banner.jpg)

# %% [markdown]
# # Keras多层感知器
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %% [markdown]
# ## 1.引入工具库

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout
from keras.optimizers import SGD
# %matplotlib inline
import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
set_session(tf.Session(config=config))

# %% [markdown]
# ## 2.数据准备
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %% [markdown]
# ### 2.1 数据读取

# %%
from keras.datasets import mnist
from keras.utils import np_utils

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Using TensorFlow backend.

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(60000, 784)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

# 做一下幅度缩放
X_train /= 255
X_test /= 255

# 把数字1，4，7等转成one-hot的形式
Y_train = np_utils.to_categorical(y_train, 10)
Y_test = np_utils.to_categorical(y_test, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-d2d1195da6f2> in <module>()
#       1 X_train = X_train.reshape(60000, 784)
# ----> 2 X_test = X_test.reshape(60000, 784)
#       3 X_train = X_train.astype("float32")
#       4 X_test = X_test.astype("float32")
#       5
#
# ValueError: cannot reshape array of size 7840000 into shape (60000,784)

# %% [markdown]
# ### 2.2 切分训练集和测试集

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train)

# %%
plt.imshow(X_train[0].reshape(28, 28))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-83ea8ac86e14> in <module>()
# ----> 1 plt.imshow(X_train[0].reshape(28, 28))
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(X_val[0].reshape(28, 28))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-365a4f16dcda> in <module>()
# ----> 1 plt.imshow(X_val[0].reshape(28, 28))
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## 3.模型构建
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=SGD(lr=0.001), 
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-10b0ad52e81e> in <module>()
# ----> 1 model = Sequential()
#       2 model.add(Dense(512, activation='relu', input_shape=(784,)))
#       3 model.add(Dropout(0.2))
#       4 model.add(Dense(512, activation='relu'))
#       5 model.add(Dropout(0.2))
#
# NameError: name 'Sequential' is not defined

# %% [markdown]
# ## 4.模型训练
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
# 可以查看模型结构
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 训练
network_history = model.fit(X_train, Y_train, batch_size=128, 
                            epochs=20, verbose=1, validation_data=(X_val, Y_val))
# Out:
# Train on 45000 samples, validate on 15000 samples
# Epoch 1/20
# 45000/45000 [==============================] - 3s 70us/step - loss: 2.2306 - acc: 0.1823 - val_loss: 2.1012 - val_acc: 0.4340
# Epoch 2/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 2.0256 - acc: 0.4238 - val_loss: 1.8895 - val_acc: 0.6676
# Epoch 3/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 1.8193 - acc: 0.5915 - val_loss: 1.6665 - val_acc: 0.7245
# Epoch 4/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 1.6071 - acc: 0.6629 - val_loss: 1.4428 - val_acc: 0.7564
# Epoch 5/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 1.4036 - acc: 0.7062 - val_loss: 1.2393 - val_acc: 0.7779
# Epoch 6/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 1.2218 - acc: 0.7368 - val_loss: 1.0706 - val_acc: 0.7970
# Epoch 7/20
# 45000/45000 [==============================] - 2s 42us/step - loss: 1.0768 - acc: 0.7578 - val_loss: 0.9387 - val_acc: 0.8121
# Epoch 8/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.9640 - acc: 0.7762 - val_loss: 0.8371 - val_acc: 0.8229
# Epoch 9/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.8775 - acc: 0.7862 - val_loss: 0.7586 - val_acc: 0.8348
# Epoch 10/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.8065 - acc: 0.8000 - val_loss: 0.6979 - val_acc: 0.8425
# Epoch 11/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.7505 - acc: 0.8083 - val_loss: 0.6497 - val_acc: 0.8479
# Epoch 12/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.7066 - acc: 0.8161 - val_loss: 0.6104 - val_acc: 0.8546
# Epoch 13/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.6709 - acc: 0.8227 - val_loss: 0.5783 - val_acc: 0.8588
# Epoch 14/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.6421 - acc: 0.8282 - val_loss: 0.5515 - val_acc: 0.8630
# Epoch 15/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.6177 - acc: 0.8318 - val_loss: 0.5293 - val_acc: 0.8665
# Epoch 16/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.5906 - acc: 0.8384 - val_loss: 0.5097 - val_acc: 0.8706
# Epoch 17/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.5732 - acc: 0.8414 - val_loss: 0.4926 - val_acc: 0.8735
# Epoch 18/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.5546 - acc: 0.8464 - val_loss: 0.4775 - val_acc: 0.8771
# Epoch 19/20
# 45000/45000 [==============================] - 2s 40us/step - loss: 0.5400 - acc: 0.8508 - val_loss: 0.4647 - val_acc: 0.8785
# Epoch 20/20
# 45000/45000 [==============================] - 2s 41us/step - loss: 0.5250 - acc: 0.8534 - val_loss: 0.4527 - val_acc: 0.8809

# %% [markdown]
# ## 5.打印训练信息
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(network_history):
    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(network_history.history['loss'])
    plt.plot(network_history.history['val_loss'])
    plt.legend(['Training', 'Validation'])

    plt.figure()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(network_history.history['acc'])
    plt.plot(network_history.history['val_acc'])
    plt.legend(['Training', 'Validation'], loc='lower right')
    plt.show()

plot_history(network_history)

# %% [markdown]
# ## 附：遍历与设置model.layers
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
print('模型输入张量: ', model.input, end='\n\n')
print('神经网络的层次信息:', end='\n\n')
for layer in model.layers:
    print(layer.name, layer.trainable)
    print('本层的设定')
    print(layer.get_config(), end='\n{}\n'.format('----'*10))
print('模型输出张量: ', model.output)
# Out:
# 模型输入张量:  Tensor("dense_1_input:0", shape=(?, 784), dtype=float32)
#
# 神经网络的层次信息:
#
# dense_1 True
# 本层的设定
# {'bias_constraint': None, 'bias_initializer': {'config': {}, 'class_name': 'Zeros'}, 'kernel_constraint': None, 'units': 512, 'use_bias': True, 'activity_regularizer': None, 'bias_regularizer': None, 'name': 'dense_1', 'kernel_initializer': {'config': {'mode': 'fan_avg', 'seed': None, 'distribution': 'uniform', 'scale': 1.0}, 'class_name': 'VarianceScaling'}, 'dtype': 'float32', 'trainable': True, 'kernel_regularizer': None, 'batch_input_shape': (None, 784), 'activation': 'relu'}
# ----------------------------------------
# dropout_1 True
# 本层的设定
# {'rate': 0.2, 'seed': None, 'trainable': True, 'noise_shape': None, 'name': 'dropout_1'}
# ----------------------------------------
# dense_2 True
# 本层的设定
# {'bias_constraint': None, 'bias_initializer': {'config': {}, 'class_name': 'Zeros'}, 'kernel_constraint': None, 'units': 512, 'use_bias': True, 'activity_regularizer': None, 'bias_regularizer': None, 'name': 'dense_2', 'kernel_initializer': {'config': {'mode': 'fan_avg', 'seed': None, 'distribution': 'uniform', 'scale': 1.0}, 'class_name': 'VarianceScaling'}, 'trainable': True, 'kernel_regularizer': None, 'activation': 'relu'}
# ----------------------------------------
# dropout_2 True
# 本层的设定
# {'rate': 0.2, 'seed': None, 'trainable': True, 'noise_shape': None, 'name': 'dropout_2'}
# ----------------------------------------
# dense_3 True
# 本层的设定
# {'bias_constraint': None, 'bias_initializer': {'config': {}, 'class_name': 'Zeros'}, 'kernel_constraint': None, 'units': 10, 'use_bias': True, 'activity_regularizer': None, 'bias_regularizer': None, 'name': 'dense_3', 'kernel_initializer': {'config': {'mode': 'fan_avg', 'seed': None, 'distribution': 'uniform', 'scale': 1.0}, 'class_name': 'VarianceScaling'}, 'trainable': True, 'kernel_regularizer': None, 'activation': 'softmax'}
# ----------------------------------------
# 模型输出张量:  Tensor("dense_3/Softmax:0", shape=(?, 10), dtype=float32)

# %% [markdown]
# ## 附：抽取中间层次与可视化
# #### \[稀牛学院 x 网易云课程\]《深度学习工程师(实战)》课程资料 by [@寒小阳](https://blog.csdn.net/han_xiaoyang)

# %%
model_truncated = Sequential()
model_truncated.add(Dense(512, activation='relu', input_shape=(784,)))
model_truncated.add(Dropout(0.2))
model_truncated.add(Dense(512, activation='relu'))

for i, layer in enumerate(model_truncated.layers):
    layer.set_weights(model.layers[i].get_weights())

model_truncated.compile(loss='categorical_crossentropy', optimizer=SGD(), 
              metrics=['accuracy'])

# %%
# 抽取特征
hidden_features = model_truncated.predict(X_train)

# %%
from sklearn.manifold import TSNE
# 降维到2维，方便可视化
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(hidden_features[:1000])

# %%
colors = np.array([x for x in 'b-g-r-c-m-y-k-purple-coral-lime'.split('-')])
colors_map = np.argmax(Y_train, axis=1)
colors_map = colors_map[:1000]
plt.figure(figsize=(10,10))
nb_classes = 10
for cl in range(nb_classes):
    indices = np.where(colors_map==cl)
    plt.scatter(X_tsne[indices,0], X_tsne[indices, 1], c=colors[cl], label=cl)
plt.legend()
plt.show()

# %% [markdown]
# ### 版权归 © 稀牛学院 所有 保留所有权利
# ![](./img/xiniu_neteasy.png)
